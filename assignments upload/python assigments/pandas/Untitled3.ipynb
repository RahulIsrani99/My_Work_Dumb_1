# %%
import pandas as pd
import numpy as np

# %%
weather_data={
    'day':['1/1/2021','2/2/2021','3/3/2023','4/4/2024','5/5/2025'],
    'temperature':[32,33,34,33,45],
    'windspeed':[6,7,7,4,2],
    'event':['rain','sunny','snow','dusky','snow']
}

# %%
df=pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2021           32          6   rain
# 1  2/2/2021           33          7  sunny
# 2  3/3/2023           34          7   snow
# 3  4/4/2024           33          4  dusky
# 4  5/5/2025           45          2   snow

# %%
row, columns=df.shape

# %%
row
# Out:
# 5

# %%
columns
# Out:
# 4

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2021           32          6   rain
# 1  2/2/2021           33          7  sunny
# 2  3/3/2023           34          7   snow
# 3  4/4/2024           33          4  dusky
# 4  5/5/2025           45          2   snow

# %%
df.head(1)
# Out:
#         day  temperature  windspeed event
# 0  1/1/2021           32          6  rain

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 3  4/4/2024           33          4  dusky
# 4  5/5/2025           45          2   snow

# %%
df[2:6]
# Out:
#         day  temperature  windspeed  event
# 2  3/3/2023           34          7   snow
# 3  4/4/2024           33          4  dusky
# 4  5/5/2025           45          2   snow

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2021
# 1    2/2/2021
# 2    3/3/2023
# 3    4/4/2024
# 4    5/5/2025
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     rain
# 1    sunny
# 2     snow
# 3    dusky
# 4     snow
# Name: event, dtype: object

# %%
df[['event','day']]
# Out:
#    event       day
# 0   rain  1/1/2021
# 1  sunny  2/2/2021
# 2   snow  3/3/2023
# 3  dusky  4/4/2024
# 4   snow  5/5/2025

# %%
df['temperature'].mean()
# Out:
# 35.4

# %%
df['temperature'].max()
# Out:
# 45

# %%
df['temperature'].min()
# Out:
# 32

# %%
df['temperature'].std()
# Out:
# 5.412947441089743

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     5.000000   5.000000
# mean     35.400000   5.200000
# std       5.412947   2.167948
# min      32.000000   2.000000
# 25%      33.000000   4.000000
# 50%      33.000000   6.000000
# 75%      34.000000   7.000000
# max      45.000000   7.000000

# %%
df[df.temperature>=40]
# Out:
#         day  temperature  windspeed event
# 4  5/5/2025           45          2  snow

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 4  5/5/2025           45

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.set_index('day', inplace=True)

# %%
df.loc['1/1/2021']
# Out:
# temperature      32
# windspeed         6
# event          rain
# Name: 1/1/2021, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2021           32          6   rain
# 1  2/2/2021           33          7  sunny
# 2  3/3/2023           34          7   snow
# 3  4/4/2024           33          4  dusky
# 4  5/5/2025           45          2   snow

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#             day  temperature  windspeed
# event
# rain   1/1/2021           32          6
# sunny  2/2/2021           33          7
# snow   3/3/2023           34          7
# dusky  4/4/2024           33          4
# snow   5/5/2025           45          2

# %%
df.loc['snow']
# Out:
#             day  temperature  windspeed
# event
# snow   3/3/2023           34          7
# snow   5/5/2025           45          2

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    event       day  temperature  windspeed
# 0   rain  1/1/2021           32          6
# 1  sunny  2/2/2021           33          7
# 2   snow  3/3/2023           34          7
# 3  dusky  4/4/2024           33          4
# 4   snow  5/5/2025           45          2

# %%
df['temperature'].max()
# Out:
# 45

# %%
df=pd.read_csv("ezz.csv")

# %%
df
# Out:
#     Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0        Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1        Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2        Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3        Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4        Y  Prepandemic      1     N        Incidental   66      F     ARLD
# ..     ...          ...    ...   ...               ...  ...    ...      ...
# 445      N     Pandemic     12   NaN       Symptomatic   72      F      NaN
# 446      N     Pandemic     12   NaN       Symptomatic   63      M      NaN
# 447      N     Pandemic     12   NaN       Symptomatic   79      F      NaN
# 448      N     Pandemic     12   NaN       Symptomatic   84      F      NaN
# 449      N     Pandemic     12   NaN        Incidental   80      F      NaN
#
#     Cirrhosis  Size  ... Surveillance_programme Surveillance_effectiveness  \
# 0           Y  22.0  ...                      Y                 Consistent
# 1           Y  40.0  ...                      Y                 Consistent
# 2           Y  52.0  ...                      Y                 Consistent
# 3           Y  80.0  ...                      N                        NaN
# 4           Y  60.0  ...                      N                        NaN
# ..        ...   ...  ...                    ...                        ...
# 445       NaN   NaN  ...                    NaN                        NaN
# 446       NaN  75.0  ...                    NaN                        NaN
# 447       NaN  63.0  ...                    NaN                        NaN
# 448       NaN  65.0  ...                    NaN                        NaN
# 449       NaN  45.0  ...                    NaN                        NaN
#
#     Mode_of_surveillance_detection Time_diagnosis_1st_Tx  \
# 0                               US                  0.47
# 1                               US                   NaN
# 2                               US                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# ..                             ...                   ...
# 445                            NaN                   NaN
# 446                            NaN                  2.93
# 447                            NaN                   NaN
# 448                            NaN                   NaN
# 449                            NaN                  0.00
#
#      Date_incident_surveillance_scan   PS Time_MDM_1st_treatment  \
# 0                                NaN  0.0                   0.70
# 1                                NaN  2.0                    NaN
# 2                                NaN  0.0                    NaN
# 3                                NaN  2.0                    NaN
# 4                                NaN  0.0                    NaN
# ..                               ...  ...                    ...
# 445                              NaN  1.0                    NaN
# 446                              NaN  0.0                   1.63
# 447                              NaN  1.0                    NaN
# 448                              NaN  2.0                    NaN
# 449                              NaN  2.0                    NaN
#
#     Time_decisiontotreat_1st_treatment Prev_known_cirrhosis  \
# 0                                  NaN                    Y
# 1                                  NaN                    Y
# 2                                  NaN                    Y
# 3                                  NaN                    Y
# 4                                  NaN                    Y
# ..                                 ...                  ...
# 445                                NaN                    Y
# 446                               1.63                    Y
# 447                                NaN                    Y
# 448                                NaN                    Y
# 449                                NaN                    Y
#
#     Months_from_last_surveillance
# 0                        7.333333
# 1                        4.033333
# 2                        5.900000
# 3                             NaN
# 4                             NaN
# ..                            ...
# 445                           NaN
# 446                           NaN
# 447                           NaN
# 448                           NaN
# 449                           NaN
#
# [450 rows x 27 columns]

# %%
df
# Out:
#     Cancer         Year  Month Bleed Mode_Presentation  Age Gender Etiology  \
# 0        Y  Prepandemic      1     N      Surveillance   68      M    NAFLD
# 1        Y  Prepandemic      1     N      Surveillance   70      M     ARLD
# 2        Y  Prepandemic      1     N      Surveillance   64      M     ARLD
# 3        Y  Prepandemic      1     N        Incidental   73      M     ARLD
# 4        Y  Prepandemic      1     N        Incidental   66      F     ARLD
# ..     ...          ...    ...   ...               ...  ...    ...      ...
# 445      N     Pandemic     12   NaN       Symptomatic   72      F      NaN
# 446      N     Pandemic     12   NaN       Symptomatic   63      M      NaN
# 447      N     Pandemic     12   NaN       Symptomatic   79      F      NaN
# 448      N     Pandemic     12   NaN       Symptomatic   84      F      NaN
# 449      N     Pandemic     12   NaN        Incidental   80      F      NaN
#
#     Cirrhosis  Size  ... Surveillance_programme Surveillance_effectiveness  \
# 0           Y  22.0  ...                      Y                 Consistent
# 1           Y  40.0  ...                      Y                 Consistent
# 2           Y  52.0  ...                      Y                 Consistent
# 3           Y  80.0  ...                      N                        NaN
# 4           Y  60.0  ...                      N                        NaN
# ..        ...   ...  ...                    ...                        ...
# 445       NaN   NaN  ...                    NaN                        NaN
# 446       NaN  75.0  ...                    NaN                        NaN
# 447       NaN  63.0  ...                    NaN                        NaN
# 448       NaN  65.0  ...                    NaN                        NaN
# 449       NaN  45.0  ...                    NaN                        NaN
#
#     Mode_of_surveillance_detection Time_diagnosis_1st_Tx  \
# 0                               US                  0.47
# 1                               US                   NaN
# 2                               US                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# ..                             ...                   ...
# 445                            NaN                   NaN
# 446                            NaN                  2.93
# 447                            NaN                   NaN
# 448                            NaN                   NaN
# 449                            NaN                  0.00
#
#      Date_incident_surveillance_scan   PS Time_MDM_1st_treatment  \
# 0                                NaN  0.0                   0.70
# 1                                NaN  2.0                    NaN
# 2                                NaN  0.0                    NaN
# 3                                NaN  2.0                    NaN
# 4                                NaN  0.0                    NaN
# ..                               ...  ...                    ...
# 445                              NaN  1.0                    NaN
# 446                              NaN  0.0                   1.63
# 447                              NaN  1.0                    NaN
# 448                              NaN  2.0                    NaN
# 449                              NaN  2.0                    NaN
#
#     Time_decisiontotreat_1st_treatment Prev_known_cirrhosis  \
# 0                                  NaN                    Y
# 1                                  NaN                    Y
# 2                                  NaN                    Y
# 3                                  NaN                    Y
# 4                                  NaN                    Y
# ..                                 ...                  ...
# 445                                NaN                    Y
# 446                               1.63                    Y
# 447                                NaN                    Y
# 448                                NaN                    Y
# 449                                NaN                    Y
#
#     Months_from_last_surveillance
# 0                        7.333333
# 1                        4.033333
# 2                        5.900000
# 3                             NaN
# 4                             NaN
# ..                            ...
# 445                           NaN
# 446                           NaN
# 447                           NaN
# 448                           NaN
# 449                           NaN
#
# [450 rows x 27 columns]
